# %% [markdown]
# # Assignment 2 starter code
# This notebook contains code to run [coreferee](https://github.com/explosion/coreferee), a coreference system running under spaCy to extract coreference chains (or clusters) from text.
# To run the notebook, you first have to intall coreferee. See instructions here: https://spacy.io/universe/project/coreferee, but mostly what you need to do is, from a command prompt:
#
# `$ python -m pip install coreferee`
#
# `$ python -m coreferee install en`
#
# You'll also need to download the spaCy large language model and the transformer model for English. It turns out, spacy has just released new versions and coreferee is not yet compatible with them, so you need to download specific versions of each model:
#
# `$ python -m pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.4.0/en_core_web_lg-3.4.0.tar.gz`
#
# `$ python -m pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.4.0/en_core_web_trf-3.4.0.tar.gz`
#
# You can also run install these things by running the next two cells instead. You'll only need to do this once.

# %% [markdown]
# ## Part 1: Installation
#
# You only need to do this **once**, no matter how many times you modify this notebook. Or you can do it from the command prompt, with the commands above. There is no harm in doing in more than once; it just takes a very long time.
#
# The first cell installs coreferee and the English model for it (coreferee works for other languages too). The second cell installs the right versions of the English models for spaCy. You need these specific versions because newer versions of the English models don't work with coreferee.

# %%
# !python -m pip install coreferee
# !python -m coreferee install en
# Out:
# Collecting coreferee
#   Downloading coreferee-1.4.1-py3-none-any.whl (182 kB)
#      -------------------------------------- 182.6/182.6 kB 1.4 MB/s eta 0:00:00
# Collecting spacy<3.6.0,>=3.0.0
#   Downloading spacy-3.5.4-cp310-cp310-win_amd64.whl (12.2 MB)
#      ---------------------------------------- 12.2/12.2 MB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (2.0.10)
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.12-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (2.28.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (3.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (2.0.8)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (1.23.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (4.64.1)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (0.9.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (1.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (22.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (5.2.1)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (65.6.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (2.4.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (3.0.9)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (1.0.5)
# Collecting pathy>=0.10.0
#   Downloading pathy-0.11.0-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.3/47.3 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (1.0.10)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Downloading pydantic-1.10.14-cp310-cp310-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (3.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.6.0,>=3.0.0->coreferee) (3.3.0)
# Collecting pathlib-abc==0.1.1
#   Downloading pathlib_abc-0.1.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.0.0->coreferee) (4.9.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.0.0->coreferee) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.0.0->coreferee) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.0.0->coreferee) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.0.0->coreferee) (2.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.0.0->coreferee) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.0.0->coreferee) (0.1.4)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.0.0->coreferee) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.6.0,>=3.0.0->coreferee) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from jinja2->spacy<3.6.0,>=3.0.0->coreferee) (2.1.1)
# Installing collected packages: pydantic, pathlib-abc, thinc, pathy, spacy, coreferee
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.6.0
#     Uninstalling pydantic-2.6.0:
#       Successfully uninstalled pydantic-2.6.0
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.2.2
#     Uninstalling thinc-8.2.2:
#       Successfully uninstalled thinc-8.2.2
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.7.2
#     Uninstalling spacy-3.7.2:
#       Successfully uninstalled spacy-3.7.2
# Successfully installed coreferee-1.4.1 pathlib-abc-0.1.1 pathy-0.11.0 pydantic-1.10.14 spacy-3.5.4 thinc-8.1.12
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pt-core-news-sm 3.7.0 requires spacy<3.8.0,>=3.7.0, but you have spacy 3.5.4 which is incompatible.
# en-core-web-sm 3.7.1 requires spacy<3.8.0,>=3.7.2, but you have spacy 3.5.4 which is incompatible.
# Collecting https://github.com/richardpaulhudson/coreferee/raw/master/models/coreferee_model_en.zip
#   Downloading https://github.com/richardpaulhudson/coreferee/raw/master/models/coreferee_model_en.zip (65.4 MB)
#      ---------------------------------------- 65.4/65.4 MB 5.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: coreferee-model-en
#   Building wheel for coreferee-model-en (pyproject.toml): started
#   Building wheel for coreferee-model-en (pyproject.toml): finished with status 'done'
#   Created wheel for coreferee-model-en: filename=coreferee_model_en-1.0.0-py3-none-any.whl size=65422509 sha256=b91f7892982a346e06cf94ea1bd83090960577f9cdf9657a716c1d82d9fe47a2
#   Stored in directory: C:\Users\User\AppData\Local\Temp\pip-ephem-wheel-cache-31xrzmcz\wheels\87\ca\93\b7c91eabb7b65a4200a75ea842a7009810982015d2dedfdc54
# Successfully built coreferee-model-en
# Installing collected packages: coreferee-model-en
# Successfully installed coreferee-model-en-1.0.0

# %%
# !python -m pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.4.0/en_core_web_lg-3.4.0.tar.gz
# !python -m pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.4.0/en_core_web_trf-3.4.0.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.4.0/en_core_web_lg-3.4.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.4.0/en_core_web_lg-3.4.0.tar.gz (587.7 MB)
#      ------------------------------------ 587.7/587.7 MB 723.7 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting spacy<3.5.0,>=3.4.0
#   Downloading spacy-3.4.4-cp310-cp310-win_amd64.whl (11.9 MB)
#      ---------------------------------------- 11.9/11.9 MB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.0.10)
# Collecting typer<0.8.0,>=0.3.0
#   Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (22.0)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (65.6.3)
# Collecting wasabi<1.1.0,>=0.9.1
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (4.64.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (5.2.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.0.12)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (1.23.5)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (1.0.5)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (0.11.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (1.10.14)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (1.0.10)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (8.1.12)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.4.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.28.1)
# Requirement already satisfied: pathlib-abc==0.1.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (4.9.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (0.1.4)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.1.1)
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py): started
#   Building wheel for en-core-web-lg (setup.py): still running...
#   Building wheel for en-core-web-lg (setup.py): finished with status 'done'
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-3.4.0-py3-none-any.whl size=587686940 sha256=909472fcfb20419742a99b80515b0607acd5fa7479feb55ad4a3adeacc064731
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\23\a6\28\5a726f1632fb7e54c872362ef5d3116e3598a13065594d7bb8
# Successfully built en-core-web-lg
# Installing collected packages: wasabi, typer, spacy, en-core-web-lg
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.2
#     Uninstalling wasabi-1.1.2:
#       Successfully uninstalled wasabi-1.1.2
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.0
#     Uninstalling typer-0.9.0:
#       Successfully uninstalled typer-0.9.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.5.4
#     Uninstalling spacy-3.5.4:
#       Successfully uninstalled spacy-3.5.4
# Successfully installed en-core-web-lg-3.4.0 spacy-3.4.4 typer-0.7.0 wasabi-0.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pt-core-news-sm 3.7.0 requires spacy<3.8.0,>=3.7.0, but you have spacy 3.4.4 which is incompatible.
# en-core-web-sm 3.7.1 requires spacy<3.8.0,>=3.7.2, but you have spacy 3.4.4 which is incompatible.
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.4.0/en_core_web_trf-3.4.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.4.0/en_core_web_trf-3.4.0.tar.gz (460.3 MB)
#      ------------------------------------ 460.3/460.3 MB 984.4 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from en-core-web-trf==3.4.0) (3.4.4)
# Collecting spacy-transformers<1.2.0,>=1.1.2
#   Downloading spacy_transformers-1.1.9-py2.py3-none-any.whl (53 kB)
#      -------------------------------------- 53.5/53.5 kB 698.3 kB/s eta 0:00:00
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (2.0.10)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (1.10.14)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (8.1.12)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (3.0.12)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (2.4.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (0.7.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (3.3.0)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (65.6.3)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (3.1.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (1.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (2.28.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (3.0.9)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (1.0.10)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (22.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (5.2.1)
# Collecting spacy-alignments<1.0.0,>=0.7.2
#   Downloading spacy_alignments-0.9.1-cp310-cp310-win_amd64.whl (187 kB)
#      -------------------------------------- 187.7/187.7 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: transformers<4.26.0,>=3.4.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.0) (4.24.0)
# Requirement already satisfied: torch>=1.6.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.0) (1.12.1)
# Requirement already satisfied: pathlib-abc==0.1.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (4.9.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (3.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (0.1.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (0.7.11)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (0.4.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.0) (0.10.1)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.0) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.0) (2022.7.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.0) (0.11.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\new folder\anaconda\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (2.1.1)
# Building wheels for collected packages: en-core-web-trf
#   Building wheel for en-core-web-trf (setup.py): started
#   Building wheel for en-core-web-trf (setup.py): still running...
#   Building wheel for en-core-web-trf (setup.py): finished with status 'done'
#   Created wheel for en-core-web-trf: filename=en_core_web_trf-3.4.0-py3-none-any.whl size=460267305 sha256=4c4820c74e0f26feed02feb309b565c95769692ae09a3bde9380dcd9b3ddf51b
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\71\52\3d\d12ac63575ed33aa156d706d1d3e9ad0459b02bffd3d946180
# Successfully built en-core-web-trf
# Installing collected packages: spacy-alignments, spacy-transformers, en-core-web-trf
# Successfully installed en-core-web-trf-3.4.0 spacy-alignments-0.9.1 spacy-transformers-1.1.9

# %%
import spacy
print(spacy.__version__)
# Out:
# 3.4.4

# %%
import spacy
nlp = spacy.load("en_core_web_lg")  # Or en_core_web_trf for the transformer model
nlp.add_pipe('coreferee')
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner', 'coreferee']

# %% [markdown]
# ## Part 2: Test coreferee

# %%
# import what we need, load the transformer model, 
# add coreferee to the spacy nlp pipeline

import coreferee, spacy
nlp = spacy.load('en_core_web_trf')
nlp.add_pipe('coreferee')

# %%
# this is just a test, so that you can see what the coreference chains look like
# you may get a CUDA warning here. As long as it's only a warning, things should run just fine

doc = nlp('Although he was very busy with his work, Peter had had enough of it. He and his wife decided they needed a holiday. They travelled to Spain because they loved the country very much.')

# %%
# now we print the coreference chains found

doc._.coref_chains.print()
# Out:
# 0: he(1), his(6), Peter(9), He(16), his(18)
# 1: work(7), it(14)
# 2: [He(16); wife(19)], they(21), They(26), they(31)
# 3: Spain(29), country(34)

# %% [markdown]
# A few things to note about the output:
#
# * We have 4 coreference chains, relating to: *Peter, work, wife(+Peter), Spain*
# * Coreferee is able to deal with cataphora, where the pronoun (*he*) appears before the referent (*Peter*)
# * Coreferee can deal with groups: *\[he+wife\], they*
# * The wife does not appear as an entity with a chain, because there is no referring expression to that entity. It only appears as part of *he and his wife*

# %%
# once we have an index for a particular referring expression, 
# we can ask coreferee to resolve it. For instance, printing
# the following expression gives us the referent for 
# the referring expression 31 (they)

print(doc._.coref_chains.resolve(doc[31]))
# Out:
# [Peter, wife]

# %% [markdown]
# ## Part 3: Run coreferee on local files

# %%
# do coreference chains for 5 documents in the data/ directory
# below is a sample for the first text

with open ("C:\\Users\\User\\SDA250Mywork\\A1_data\\5c1548a31e67d78e2771624f.txt", "r", encoding='utf-8') as f:
    text1 = f.read()

# %%
with open ("C:\\Users\\User\\SDA250Mywork\\A1_data\\5c15488f1e67d78e277161d7.txt", "r", encoding='utf-8') as f:
    text2 = f.read()

# %%
with open ("C:\\Users\\User\\SDA250Mywork\\A1_data\\5c149ffc1e67d78e276fbd44.txt", "r", encoding='utf-8') as f:
    text3 = f.read()

# %%
with open ("C:\\Users\\User\\SDA250Mywork\\A1_data\\5c146e42795bd2fcce2ea8e5.txt", "r", encoding='utf-8') as f:
    text4 = f.read()

# %%
with open ("C:\\Users\\User\\SDA250Mywork\\A1_data\\5c1452701e67d78e276ee126.txt", "r", encoding='utf-8') as f:
    text5 = f.read()

# %%
doc1 = nlp(text1)
doc2 = nlp(text2)
doc3 = nlp(text3)
doc4 = nlp(text4)
doc5 = nlp(text5)

# %%
doc1._.coref_chains.print()
doc2._.coref_chains.print()
doc3._.coref_chains.print()
doc4._.coref_chains.print()
doc5._.coref_chains.print()
# Out:
# 0: derailment(22), derailment(51)
# 1: order(42), It(55)
# 2: Field(160), Field(191)
# 3: B.C.(162), B.C.(193)
# 4: train(171), its(182), it(196), its(200), train(206)
# 5: Board(254), company(268)
# 6: report(264), It(281)
# 7: railway(337), its(341), its(347)
# 8: Trains(411), their(426)
# 9: train(488), it(498)
# 10: Mulligan(506), Mulligan(529)
# 11: United(510), it(531)
# 12: train(543), train(556)
# 13: railway(582), it(588)
# 14: dryers(634), them(653)
# 15: moisture(639), it(648)
# 16: Young(776), he(778)
# 17: That(793), It(810)
# 0: Liberals(44), people(56)
# 1: people(95), they(99), themselves(108)
# 2: CO2(188), It(196)
# 3: companies(214), they(220)
# 4: sector(228), it(243)
# 5: immigrant(333), his(383)
# 6: tax(340), it(351)
# 7: Ford(487), Ford(572)
# 8: this(491), it(501), itself(511)
# 9: posts(519), posts(549)
# 10: children(656), they(666)
# 11: daughter(707), herself(719), her(726)
# 12: tax(862), it(868)
# 13: households(899), them(902)
# 14: Columbia(915), it(938)
# 0: Talos(97), firm(157), its(160)
# 1: emails(122), they(134)
# 2: senders(172), they(189)
# 3: Talos(202), company(207)
# 4: attackers(274), attackers(330)
# 5: emails(277), them(292)
# 6: post(308), post(315)
# 7: Director(341), he(385)
# 8: WATCH(359), it(378)
# 9: Haley(393), he(458), Haley(464)
# 10: attack(440), it(451)
# 11: RCMP(503), he(530)
# 12: people(525), they(546), they(552), they(560), them(582), they(586)
# 13: Haley(565), He(594)
# 14: this(571), it(575), it(580)
# 15: bitcoin(627), he(674)
# 16: that(647), It(651), it(655), it(659), It(682)
# 17: threat(694), it(697)
# 18: Haley(706), he(749), Haley(804)
# 19: people(738), They(763), they(784)
# 20: ransom(742), it(746), it(752), ransom(795)
# 21: emails(818), them(824), their(826)
# 0: station(21), station(53), its(62)
# 1: Hemming(106), Hemming(131), his(137)
# 2: group(138), its(140), its(150)
# 3: Dunphy(165), he(196), he(225), his(228)
# 4: This(216), It(232)
# 5: judge(279), he(283)
# 6: Hemming(318), he(320), his(322), Hemming(372), his(374)
# 7: meeting(389), meeting(398)
# 8: JAZZ.FM91(419), JAZZ.FM91(424), its(434)
# 9: investigation(448), investigation(481)
# 10: Porter(473), his(475), he(484), he(488), he(497), his(499), his(504)
# 11: members(523), they(527), Their(535)
# 12: station(609), station(645), it(654), its(670), station(697), it(725)
# 13: 186,000(627), its(629)
# 14: Hemming(661), Hemming(730)
# 15: Dunphy(680), he(682), he(694)
# 16: democracy(709), it(714)
# 17: director(737), he(742)
# 18: Manzoli(756), he(760)
# 0: hailing(23), it(26)
# 1: Uber(47), Uber(85), Uber(105), It(127)
# 2: McCallum(58), McCallum(73)
# 3: Hayne(116), his(119)
# 4: McCallum(143), himself(147)
# 5: mayor(166), his(185)
# 6: mayor(220), his(238), his(243), his(264), he(382), he(435)
# 7: costs(334), they(347)
# 8: claims(377), claims(403)
# 9: voters(433), their(439)
# 10: McCallum(445), McCallum(477)
# 11: Telford(567), Telford(602)
# 12: McCallum(578), he(590), McCallum(606), him(628)
# 13: News(624), News(659)
# 14: mayor(639), he(664)
# 15: McCallum(726), McCallum(736), his(754)
# 16: cost(813), cost(826)
# 17: 24/7(835), it(843)
# 18: mayor(935), he(982), he(998)
# 19: media(948), they(991)
# 20: Line(1056), Line(1065), Line(1113), Line(1140)
# 21: Oct.(1104), It(1108), Its(1125)
# 22: Surrey(1226), they(1238)
# 23: half(1243), they(1247)
# 24: Council(1322), Council(1356)
# 25: TransLink(1360), it(1377)
# 26: mayor(1406), he(1435), his(1438), he(1452)
# 27: Telford(1419), he(1425), Telford(1460)
# 28: case(1433), it(1449)
# 29: Surrey(1488), Surrey(1511), City(1540), Surrey(1542)
# 30: McCallum(1505), he(1548)
# 31: city(1606), city(1669)
# 32: McCallum(1613), McCallum(1650), he(1660)
# 33: he(1738), McCallum(1746)
# 34: that(1790), It(1801)
# 35: McCallum(1884), McCallum(1919), he(2012)
# 36: city(1926), its(1930)
# 37: Cloverdale(1948), Cloverdale(1961)
# 38: ones(2003), they(2098)
# 39: arenas(2105), arenas(2120)
# 40: this(2213), it(2225)
# 41: that(2249), it(2259)
# 42: Attempts(2307), they(2349)
# 43: hockey(2457), it(2461)
# 44: chart(2491), chart(2512)
# 45: decline(2498), decline(2524)
# 46: axes(2509), axes(2519)
# 47: chart(2607), it(2609), chart(2644)
# 48: arenas(2702), them(2779)
# 49: graph(2712), graph(2729)
# 50: Secord(2717), she(2787)
# 51: numbers(2823), numbers(2840)
# 52: Council(2865), it(2867), its(2870), its(2874), its(2885)

# %%
# example: who does she(452) refer to?

print(doc1._.coref_chains.resolve(doc1[452]))
print(doc2._.coref_chains.resolve(doc1[452]))
print(doc3._.coref_chains.resolve(doc1[452]))
print(doc4._.coref_chains.resolve(doc1[452]))
print(doc5._.coref_chains.resolve(doc1[452]))
# Out:
# None
# None
# None
# None
# None

# %%
doc1._.coref_chains.print()
doc2._.coref_chains.print()
doc3._.coref_chains.print()
doc4._.coref_chains.print()
doc5._.coref_chains.print()
# Out:
# 0: derailment(22), derailment(51)
# 1: order(42), It(55)
# 2: Field(160), Field(191)
# 3: B.C.(162), B.C.(193)
# 4: train(171), its(182), it(196), its(200), train(206)
# 5: Board(254), company(268)
# 6: report(264), It(281)
# 7: railway(337), its(341), its(347)
# 8: Trains(411), their(426)
# 9: train(488), it(498)
# 10: Mulligan(506), Mulligan(529)
# 11: United(510), it(531)
# 12: train(543), train(556)
# 13: railway(582), it(588)
# 14: dryers(634), them(653)
# 15: moisture(639), it(648)
# 16: Young(776), he(778)
# 17: That(793), It(810)
# 0: Liberals(44), people(56)
# 1: people(95), they(99), themselves(108)
# 2: CO2(188), It(196)
# 3: companies(214), they(220)
# 4: sector(228), it(243)
# 5: immigrant(333), his(383)
# 6: tax(340), it(351)
# 7: Ford(487), Ford(572)
# 8: this(491), it(501), itself(511)
# 9: posts(519), posts(549)
# 10: children(656), they(666)
# 11: daughter(707), herself(719), her(726)
# 12: tax(862), it(868)
# 13: households(899), them(902)
# 14: Columbia(915), it(938)
# 0: Talos(97), firm(157), its(160)
# 1: emails(122), they(134)
# 2: senders(172), they(189)
# 3: Talos(202), company(207)
# 4: attackers(274), attackers(330)
# 5: emails(277), them(292)
# 6: post(308), post(315)
# 7: Director(341), he(385)
# 8: WATCH(359), it(378)
# 9: Haley(393), he(458), Haley(464)
# 10: attack(440), it(451)
# 11: RCMP(503), he(530)
# 12: people(525), they(546), they(552), they(560), them(582), they(586)
# 13: Haley(565), He(594)
# 14: this(571), it(575), it(580)
# 15: bitcoin(627), he(674)
# 16: that(647), It(651), it(655), it(659), It(682)
# 17: threat(694), it(697)
# 18: Haley(706), he(749), Haley(804)
# 19: people(738), They(763), they(784)
# 20: ransom(742), it(746), it(752), ransom(795)
# 21: emails(818), them(824), their(826)
# 0: station(21), station(53), its(62)
# 1: Hemming(106), Hemming(131), his(137)
# 2: group(138), its(140), its(150)
# 3: Dunphy(165), he(196), he(225), his(228)
# 4: This(216), It(232)
# 5: judge(279), he(283)
# 6: Hemming(318), he(320), his(322), Hemming(372), his(374)
# 7: meeting(389), meeting(398)
# 8: JAZZ.FM91(419), JAZZ.FM91(424), its(434)
# 9: investigation(448), investigation(481)
# 10: Porter(473), his(475), he(484), he(488), he(497), his(499), his(504)
# 11: members(523), they(527), Their(535)
# 12: station(609), station(645), it(654), its(670), station(697), it(725)
# 13: 186,000(627), its(629)
# 14: Hemming(661), Hemming(730)
# 15: Dunphy(680), he(682), he(694)
# 16: democracy(709), it(714)
# 17: director(737), he(742)
# 18: Manzoli(756), he(760)
# 0: hailing(23), it(26)
# 1: Uber(47), Uber(85), Uber(105), It(127)
# 2: McCallum(58), McCallum(73)
# 3: Hayne(116), his(119)
# 4: McCallum(143), himself(147)
# 5: mayor(166), his(185)
# 6: mayor(220), his(238), his(243), his(264), he(382), he(435)
# 7: costs(334), they(347)
# 8: claims(377), claims(403)
# 9: voters(433), their(439)
# 10: McCallum(445), McCallum(477)
# 11: Telford(567), Telford(602)
# 12: McCallum(578), he(590), McCallum(606), him(628)
# 13: News(624), News(659)
# 14: mayor(639), he(664)
# 15: McCallum(726), McCallum(736), his(754)
# 16: cost(813), cost(826)
# 17: 24/7(835), it(843)
# 18: mayor(935), he(982), he(998)
# 19: media(948), they(991)
# 20: Line(1056), Line(1065), Line(1113), Line(1140)
# 21: Oct.(1104), It(1108), Its(1125)
# 22: Surrey(1226), they(1238)
# 23: half(1243), they(1247)
# 24: Council(1322), Council(1356)
# 25: TransLink(1360), it(1377)
# 26: mayor(1406), he(1435), his(1438), he(1452)
# 27: Telford(1419), he(1425), Telford(1460)
# 28: case(1433), it(1449)
# 29: Surrey(1488), Surrey(1511), City(1540), Surrey(1542)
# 30: McCallum(1505), he(1548)
# 31: city(1606), city(1669)
# 32: McCallum(1613), McCallum(1650), he(1660)
# 33: he(1738), McCallum(1746)
# 34: that(1790), It(1801)
# 35: McCallum(1884), McCallum(1919), he(2012)
# 36: city(1926), its(1930)
# 37: Cloverdale(1948), Cloverdale(1961)
# 38: ones(2003), they(2098)
# 39: arenas(2105), arenas(2120)
# 40: this(2213), it(2225)
# 41: that(2249), it(2259)
# 42: Attempts(2307), they(2349)
# 43: hockey(2457), it(2461)
# 44: chart(2491), chart(2512)
# 45: decline(2498), decline(2524)
# 46: axes(2509), axes(2519)
# 47: chart(2607), it(2609), chart(2644)
# 48: arenas(2702), them(2779)
# 49: graph(2712), graph(2729)
# 50: Secord(2717), she(2787)
# 51: numbers(2823), numbers(2840)
# 52: Council(2865), it(2867), its(2870), its(2874), its(2885)

# %%
# print referring expressions that are people
# we are interested in those because they are the sources of quotes
for ent in doc1.ents:
    if ent.label_ in ["PERSON"]:
        print(ent.text, ent.label_)
# Out:
# Marc Garneau PERSON
# Garneau PERSON
# Andrew Dockrell PERSON
# Dylan Paradis PERSON
# Daniel Waldenberger-Bulmer PERSON
# Joe Mulligan PERSON
# Mulligan PERSON
# Will Young PERSON

# %%
# print referring expressions that are people
# we are interested in those because they are the sources of quotes
for ent in doc2.ents:
    if ent.label_ in ["PERSON"]:
        print(ent.text, ent.label_)
# Out:
# Trudeau PERSON
# Justin Trudeau PERSON
# Earl Hyde PERSON
# Jane White PERSON
# Trudeau PERSON
# Earl G. Hyde PERSON
# Maggie Laidlaw PERSON
# Joel Maziarski PERSON
# Walkom PERSON
# Thomas Walkom PERSON
# Rebecca Weigand PERSON
# Rick Salutin PERSON
# Macron PERSON
# Doug Pritchard PERSON

# %%
# print referring expressions that are people
# we are interested in those because they are the sources of quotes
for ent in doc3.ents:
    if ent.label_ in ["PERSON"]:
        print(ent.text, ent.label_)
# Out:
# Jason Schultz PERSON
# Kevin Haley PERSON
# Haley PERSON
# Haley PERSON
# Haley PERSON
# Haley PERSON
# Haley PERSON

# %%
# print referring expressions that are people
# we are interested in those because they are the sources of quotes
for ent in doc4.ents:
    if ent.label_ in ["PERSON"]:
        print(ent.text, ent.label_)
# Out:
# Sean Dunphy PERSON
# Brian Hemming PERSON
# Hemming PERSON
# Hemming PERSON
# Dunphy PERSON
# Hemming PERSON
# Reagan Ruslim PERSON
# Hemming PERSON
# Hemming PERSON
# Ross Porter PERSON
# Porter PERSON
# Hemming PERSON
# Dunphy PERSON
# Hemming PERSON
# Joseph Manzoli PERSON

# %%
# print referring expressions that are people
# we are interested in those because they are the sources of quotes
for ent in doc5.ents:
    if ent.label_ in ["PERSON"]:
        print(ent.text, ent.label_)
# Out:
# Doug McCallum PERSON
# McCallum PERSON
# Bruce Hayne PERSON
# McCallum PERSON
# McCallum PERSON
# McCallum PERSON
# Cindy Dalglish PERSON
# McCallum PERSON
# Hamish Telford PERSON
# McCallum PERSON
# McCallum PERSON
# McCallum PERSON
# McCallum PERSON
# McCallum PERSON
# Hatch PERSON
# McCallum PERSON
# McCallum PERSON
# John Horgan PERSON
# Kevin Desmond PERSON
# McCallum PERSON
# McCallum PERSON
# McCallum PERSON
# McCallum PERSON
# McCallum PERSON
# McCallum PERSON
# McCallum PERSON
# Marty Jones PERSON
# McCallum PERSON
# Cindy Secord PERSON

# %% [markdown]
# ## Side note: visualizations
# If you want to see this all in a much prettier format, you can use [displacy](https://spacy.io/usage/visualizers).

# %%
from spacy import displacy

# %%
options = {"ents": ["PERSON"],
          "colors": {"PERSON": "lightsteelblue"}}

displacy.render(doc1, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">CALGARY — Canada's transport minister has ordered the use of handbrakes on all trains stopped on mountain slopes following a deadly derailment earlier this week in the Rocky Mountains. </br>
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marc Garneau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said in a statement late Friday that the order is a precaution until the cause of the derailment is determined. It takes effect immediately. </br> &quot;My department has issued a Ministerial Order under the Railway Safety Act to all railway companies mandating the use of handbrakes should a train be stopped on a mountain grade after an emergency use of the air brakes. This order takes effect immediately and will remain in effect as long as necessary,&quot; said
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Garneau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . </br> &quot;As I have said many times before, rail safety is my top priority and I will never hesitate to take appropriate actions when necessary.&quot;. </br> The Canadian Press A train derailment is shown near Field, B.C. on Monday. </br> A Vancouver-bound train with 112 grain cars was parked for two hours with its air brakes engaged on a grade east of Field, B.C., when it started moving on its own early Monday. The train sped up to well over the limit before 99 cars and two locomotives hurtled off the tracks. </br> Three employees with Canadian Pacific Railway — engineer
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Andrew Dockrell
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , conductor
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dylan Paradis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and trainee
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Daniel Waldenberger-Bulmer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  — were killed. </br> The Transportation Safety Board has said handbrakes were not applied. </br> A report by the railway company details how challenging it is to run trains in frigid temperatures. It was about -20 C at the time of the crash. </br> &quot;Harsh winter conditions are an inescapable reality in Canada's northern climate,&quot; says a document titled White Paper: Railroading in the Canadian Winter on Canadian Pacific Railway's website. </br> &quot;Winter has a profound impact on a railway's operations and its ability to maintain service for its customers.&quot;. </br> The Canadian Press A train derailment is shown near Field, B.C. on Monday. </br> The white paper said cold increases air leakage from a train's air- brake system that results in varying air pressures between the head and tail end of a train. </br> &quot;This is a major challenge.&quot;. </br> Trains are shortened when temperatures dip below -25 C to ensure pressure remains consistent throughout their entire length, the report said. </br> A union representative has said the derailed train was shorter than the 135 cars CP has run in recent years. But a veteran Boston-based engineer said 112 cars is large for a train of full grain hoppers. </br> &quot;Our forefathers in the business would never have put a train together that big under those climatic conditions and expected it to run smoothly,&quot; said
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Mulligan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  with Railroad Workers United, a volunteer-run group of rank-and-file railroaders across North America. </br>
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mulligan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said it would have taken a lot of handbrakes to hold back a train so big. And there was nothing to be done once the train was in motion. </br> The Canadian Press A train derailment is shown near Field, B.C. on Monday. </br> The Calgary-based railway said in the report that it also places locomotives at different points along a train in the winter. Distributing power that way makes it quicker to pressurize air brakes. The train that derailed had a locomotive at the front, middle and end. </br> In extreme cold, dryers are used to prevent moisture from getting into the brakes, which means it takes longer to pressurize them and do the required safety checks, said the winter railroading report. </br> &quot;This unavoidably increases the train's terminal dwell time.&quot;. </br> The white paper also said train speeds must be reduced in frigid temperatures — by at least 16 km/h below -25 C and by at least 32 km/h at -35 C. </br> Will Young, a locomotive mechanic based in Kansas City, Mo., and an organizer at Railroad Workers United, said cold weather takes a toll on many train components. </br> &quot;Things break that normally don't. Steel just becomes brittle. Rubber seals just harden and don't work.&quot;. </br> Young said he suspects some sort of mechanical issue caused the braking system to lose power. That could have set off the chain of events that led to the catastrophe. </br> &quot;It only takes that ever-so-slight touch of momentum.&quot;. </br> Also on HuffPost:</div></span>

# %%
options = {"ents": ["PERSON"],
          "colors": {"PERSON": "lightsteelblue"}}

displacy.render(doc2, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ford and
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trudeau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  trade shots on climate change plans, Dec. 8 We are now in crisis mode with the environment. Our government’s pathetic attempt at reducing global warming has not been of any use. </br> “
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Justin Trudeau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and the Liberals should pay attention to the riots happening in France. The people are revolting against carbon taxes, open immigration and the arrogance of the progressive socialist government,”
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earl Hyde
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  of Brantford writes. ( JEAN-PHILIPPE KSIAZEK / AFP/GETTY IMAGES ). </br> Punishing people with taxes because they need to get around or want to keep themselves warm in the winter is no solution at all. Good riddance to the cap and trade — or “pay up and pollute all you want” — initiative. We need real scientific solutions, such as forcing builders to make homes and buildings more energy efficient and sustainable. We need clean energy for transportation and home heating. Also, we must protect and expand our green spaces and plant more trees, which absorb CO2. There are solutions out there. It just takes some genuine government involvement to get things moving in that direction. If the oil companies are holding us back, they must be ignored. The clean energy sector can create jobs, too. The planet and our very lives depend on it. </br> Article Continued Below. </br>
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jane White
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Scarborough Canada, which contributes less that 1.6 per cent of overall greenhouse gases, is being forced to pay carbon taxes while China opens a new coal-fired generating plant every week. If you support the climate change theory, you should stop driving a car, stop using carbon-based electricity, and stop using anything that is made of carbon. If you support open immigration, you should welcome and support an immigrant in your home. The carbon tax and open immigration should be voluntary and those who support it should pay. The progressives are hypocrites and never walk the talk. When we have finally had enough, the yellow vests in Canada will stand up to
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trudeau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and his politically correct progressive elites. </br>
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earl G. Hyde
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Brantford The Dunkirk analogy, far from being disrespectful, is entirely appropriate in the context of the greatest threat our planet is experiencing. Unless ordinary people like us rally against the climate change deniers in both the federal and provincial Conservative parties, we are marching toward climate catastrophe. </br> Article Continued Below. </br> To paraphrase a well-known expression, “While Conservatives fiddle, the planet burns!” Bravo to our Guelph MPP.
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maggie Laidlaw
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Guelph This “goal post” talk reflects Ford’s view that this is all some sort of political game, when it is actually about the preservation of Earth and life itself. Science tells us that the goal posts of catastrophic climate change have already been cemented in place via human greed, and the politicians who prioritize corporate profit over public good keep us hurtling toward these posts at breakneck speed. If you want to talk about unfair, try living in a world where someone as ignorant as Ford can somehow rise to political power.
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joel Maziarski
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Toronto Climate fears are real, so oilsands must close,
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Walkom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Dec. 5 Thank you to
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thomas Walkom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  for this thoughtful column. There is a growing movement of young people calling for climate action and environmental justice, through school strikes, sit-ins and a recent lawsuit in Quebec against the federal government’s failure to take meaningful action. Parents and teachers want the best for our children. But we are busy and anxious providing what they need to thrive now, so it’s hard to look to the future at something over which we seem to have so little control. As a new parent, there is nothing I want more than for my daughter to grow up in a stable climate, not only for herself. And I don’t want her to have the weight of knowing that children in other places are facing hunger, flooding or displacement because we didn’t act. If we come together in solidarity with the youth, we have power. In Canada, we can lead the way to the rapid and intense climate action the planet needs. No new fossil-fuel infrastructure. We need high and rising carbon taxes returned to the taxpayers and intense investment in green infrastructure, jobs and social justice infrastructure.
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rebecca Weigand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , TorontoFrance’s yellow vests and the tarsands of Alberta, Salutin, Dec. 7
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rick Salutin
#     <span style="font-size: 0.8em; font-w

# %%
options = {"ents": ["PERSON"],
          "colors": {"PERSON": "lightsteelblue"}}

displacy.render(doc3, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Security experts believe Thursday’s emailed bomb threats can be traced back to the same group responsible for the “sextortion” scam this past October. </br> While investigators still do not know who is responsible, Cisco System’s Talos cybersecurity unit said in a statement on Friday that the threats came from the same group of fraudsters responsible for sending emails a few months back that claimed to have videos showing the recipients having sex. </br> READ MORE: Sextortion scam uses old passwords to extort money from victims. </br> “Cisco Talos discovered that this campaign is actually an evolution of sextortion and extortion attacks that we reported on in October. The claims in the emails we’ve seen from this actor are completely false, yet they have caused untold amounts of damage as organizations have evacuated buildings and called upon law enforcement to investigate,” the security firm wrote in its statement. </br> In the “sextortion” case, the senders threatened to release these videos, recorded through the webcams on recipients’ computers, unless they were paid a ransom. </br>
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jason Schultz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , technical researcher at Talos, stated in the company’s blog post that some of the bomb threats that took place this week came from the same addresses used in those campaigns. </br> WATCH: Bomb threats demanding Bitcoin investigated across Canada, U.S. </br> “Multiple IPs involved in sending these bomb threats also sent various types of sextortion email that we saw in the previous campaign. In those cases, the attackers sent out emails claiming to have compromising videos of the victim and (threatened to) release them to the public unless the attacker (received) a bitcoin payment,” the post read. </br> According to the post, the bomb threat had morphed once again by late Thursday, as the attackers now threatened to throw acid on the victims. </br> Director, security response at cybersecurity firm Symantec,
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kevin Haley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , agreed with this finding. </br> WATCH: Authorities outline ‘sextortion’ string involving inmates, military service members. </br> “We believe it’s the same group,” he confirmed. </br> To determine this,
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Haley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  explained that Symantec looked at where the threats where coming from, the characteristics of the emails and whether or not the same spam servers were being used in this case as were used in October. </br> “We’re looking for similarities in the attack and when you see those similarities you pretty much know it’s the same group,” he said. </br> According to
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Haley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the bomb threats were an “innovation” on October’s “sextortion” scam, and the threat will likely continue to evolve until the perpetrators stumble upon one that sticks. </br> WATCH: Burnaby RCMP warns of rise in ‘sextortion’ cases. </br> “This game is all about getting a certain percentage of people to respond,” he said. </br> “The sextortion spam is not new. What’s new is they had a new twist that they thought could increase the amount of money they could make,”
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Haley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  explained. </br> “While this caused chaos, it doesn’t look like it made them any money so they’ve moved on.”. </br> He states however, that the increased frequency of these kinds of threats has less to do with access to technology and more to do with the option to demand ransom payments in bitcoin. </br> “What’s different here is that there is an easy way to exploit people, and that’s cryptocurrency. It’s fast, it’s virtual and it’s almost risk-free for the bad guys to do that,” he said. </br> READ MORE: ‘It becomes a nightmare’: the rise of the viral bomb threat and how it makes the job of police harder. </br>
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Haley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said that though the attackers didn’t make any money this time, we’re likely to see more of this style of attack containing different threats until one prompts enough people to pay the ransom. And when it does, he warns that it’s going to “explode.”. </br> “They’re going to continue to throw things up against the wall and see what sticks until, eventually, when they hit at something that motivates people to actually pay that ransom, we’ll see that explode,”
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Haley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. “We’ll see hundreds of thousands, millions of these emails. Everybody will start getting them in their mailbox.”</div></span>

# %%
options = {"ents": ["PERSON"],
          "colors": {"PERSON": "lightsteelblue"}}

displacy.render(doc4, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A Superior Court of Ontario judge chastised JAZZ.FM91 on Friday morning, saying the not-for-profit Toronto radio station had been “playing games” to prevent a dissident shareholder group from lobbying members for changes in the organization’s board of directors. </br> Justice
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sean Dunphy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  directed the station to provide the e-mail addresses of its approximately 2,200 member-donors to
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brian Hemming
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a Toronto-investment relations consultant and founder of Save Jazz FM. The group was founded in the summer after an eruption of discontent among supporters. </br> The station had provided Mr.
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hemming
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  with names and addresses of members, but refused to include e-mail addresses or phone numbers, citing privacy concerns. Mr.
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hemming
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  argued that the move disadvantaged his group in its dispute, noting the station’s board frequently lobbies its members through e-mails. </br> Story continues below advertisement. </br> Justice
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dunphy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said the station’s defiant stand “was clearly adopted to frustrate the applicants and not – as suggested – out of concern to maintain privacy.” Still, he denied Mr.
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hemming
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s request for phone numbers, characterizing that method of contact as intrusive. </br> “This has degenerated into an acrimonious fight,” he wrote in his decision. “It needn’t be so adversarial.”. </br> A statement e-mailed to The Globe by
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reagan Ruslim
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who joined the board last month, said “JAZZ.FM91 will respect the order of the Court.” When asked for comment about the judge’s criticisms, he replied the station would “have a further statement next week. Stay tuned!”. </br> During an interview outside the small courtroom, which had been packed with supporters, Mr.
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hemming
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said he and his group were “very pleased with the decision. This really just levels the playing field and gives us an opportunity to talk to members about what our proposals are – and that’s all we ever wanted.”. </br> In a statement issued later, Mr.
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hemming
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said his group intended to use the e-mail addresses to press for a special meeting of members. “The purpose of the meeting would be to vote out the incumbent board and then vote in a new board of directors proposed by Save JAZZ.FM91.”. </br> JAZZ.FM91 has been in turmoil since the spring, when its president and CEO,
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ross Porter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , departed in the wake of an investigation into allegations of workplace bullying, harassment, and sexual harassment. (In a statement to the Globe at the time, Mr.
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Porter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  denied his departure was connected to the investigation. When he stepped down, he was given the title of president emeritus and he retained his position as host of his own Saturday morning radio program.). </br> As news of the allegations began to surface, members complained about what they said was a lack of transparency. Their discontent escalated after the station laid off a number of popular on-air personalities in June, leaving many time slots without a host. At the annual general meeting in late August, dozens of members turned out to voice anger and disappointment with the station’s board and management. </br> Story continues below advertisement. </br> Story continues below advertisement. </br> The disarray appears to be affecting the station’s financial picture: The most recent fundraising drive, held last month, raised only $186,000 of its $350,000 goal. </br> The fight over e-mail addresses will cost the station approximately $50,000, after the judge ordered it to pay $20,000 of Mr.
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hemming
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s estimated $50,000 costs in addition to its own $30,000 of incurred costs. Though Justice
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dunphy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said he was loath to penalize a not-for-profit, he believed the station had acted improperly by “tossing roadblocks in the way of democracy,” and “it would be sending the wrong message” to not charge it some share of Mr.
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hemming
#     <span style="font-si

# %%
options = {"ents": ["PERSON"],
          "colors": {"PERSON": "lightsteelblue"}}

displacy.render(doc5, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The question was common for mayoral candidates to hear back in the October municipal election: what do you think of ride-hailing and should it come to Metro Vancouver?. </br> “I was clear when I was mayor – I don’t support Uber at all,” then-Surrey mayoral candidate
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Doug McCallum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  responded at one debate. </br> It was an odd thing to say:
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     McCallum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s last term as Surrey mayor ended in 2005, while Uber as a company began in 2009, briefly entering the Vancouver market only in 2012. There was no Uber not to support in 2005. </br> Rival candidate
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bruce Hayne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  joked in his turn to answer the question, “It was a twinkle in some engineer’s eye some years ago.”. </br>
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     McCallum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  didn’t correct himself. </br> But the strange remark may have foreshadowed a growing number of curious statements from the returning mayor of B.C.’s second-largest, rapidly growing city, which is wrestling with big changes after his come-from-behind election win. </br> CTV News has analyzed about three weeks' worth of
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     McCallum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's speeches, statements at public meetings, and press conferences to find the mayor’s claims, in some cases, don’t stand up to inspection. </br> Sometimes, his claims seem to further his political agenda, such as exaggerating a drop in the children participating in ice sports, which was part of his argument to cut the previous administration's projects, including a $44.5 million Cloverdale Sport and Ice Complex. </br> A claim the city's debt is higher than city reports say it is could support a total of $135 million in proposed cuts to the previous administration's projects, including the $58 million Grandview Heights Community Centre and Library. </br> A claim the costs of building a SkyTrain extension to Langley are lower than TransLink says they are could make one of McCallum's two big-ticket promises, SkyTrain and a municipal police force, more attractive. </br> But other times, the claims, such as what he said about Uber, do not seem to advance any particular political agenda. To make our list, the claims had to be on camera, at a public meeting or addressed to the press, and not be corrected as a one-off error. </br> Some voters say he is already losing their trust. </br> “Mayor
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     McCallum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s statements vary greatly from truth,”
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cindy Dalglish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  told Surrey’s councillors at Tuesday’s finance committee meeting. </br> But observers say there may be a method to
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     McCallum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s messages. </br> “There’s a tried-and-true method in Canadian politics: after an election a new government takes office and says, ‘Oh my gosh, the cupboards are bare.’ Or, ‘We’re much deeper in debt than I thought we were, and now I’ve seen the real books.' So I think there’s an element of that kind of gamesmanship going on,” University of the Fraser Valley political scientist
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hamish Telford
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. </br> “Then there’s the fact that
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     McCallum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has been out of office for quite some time, thinking he knew the job, but some things have changed,” Telford said. </br>
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     McCallum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  didn’t respond to interview requests on these topics through City of Surrey staff, so CTV News caught up with him at Thursday’s Mayors' Council meeting. </br> The mayor didn’t respond directly to questions about whether there’s a pattern to advancing these claims, but CTV News has included the response he did give in each section below. </br> . </br> Citing a nonexistent TransLink study. </br> “If you take Fraser Highway SkyTrain and if we’re building that seven days a week around the clock, we probably can save, and this is TransLink’s figures, we can probably save $2-300 million,”
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     McCallum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  told the Mayors Council on Nov. 15. </br>
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     McCallum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s speech to fellow municipal leaders was a crucial part of getting the region on board with his plan to switch from the Newton-Surrey-Guildford LRT to a SkyTrain extension to Langley. </br> Mayors were understandably concerned about the cost of the move to a Langley SkyTrain, which a TransLink study in 2017 concluded would cost between
